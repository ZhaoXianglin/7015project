# %%
from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout
from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.utils.np_utils import to_categorical
from keras.callbacks import ModelCheckpoint
from load_data import load_data
from sklearn.model_selection import train_test_split
import numpy as np


# 创建模型序列VGG19
model = Sequential()  
model.add(Conv2D(64,(3,3),strides=(1,1),input_shape=(224,224,3),padding='same',activation='relu',kernel_initializer='uniform'))  
model.add(Conv2D(64,(3,3),strides=(1,1),padding='same',activation='relu',kernel_initializer='uniform'))  
model.add(MaxPooling2D(pool_size=(2,2)))  
model.add(Conv2D(128,(3,3),strides=(1,1),padding='same',activation='relu',kernel_initializer='uniform'))  
model.add(Conv2D(128,(3,3),strides=(1,1),padding='same',activation='relu',kernel_initializer='uniform'))  
model.add(MaxPooling2D(pool_size=(2,2)))  
model.add(Conv2D(256,(3,3),strides=(1,1),padding='same',activation='relu',kernel_initializer='uniform'))  
model.add(Conv2D(256,(3,3),strides=(1,1),padding='same',activation='relu',kernel_initializer='uniform'))  
model.add(Conv2D(256,(3,3),strides=(1,1),padding='same',activation='relu',kernel_initializer='uniform'))  
model.add(Conv2D(256,(3,3),strides=(1,1),padding='same',activation='relu',kernel_initializer='uniform'))  
model.add(MaxPooling2D(pool_size=(2,2)))  
model.add(Conv2D(512,(3,3),strides=(1,1),padding='same',activation='relu',kernel_initializer='uniform'))  
model.add(Conv2D(512,(3,3),strides=(1,1),padding='same',activation='relu',kernel_initializer='uniform'))  
model.add(Conv2D(512,(3,3),strides=(1,1),padding='same',activation='relu',kernel_initializer='uniform'))  
model.add(Conv2D(512,(3,3),strides=(1,1),padding='same',activation='relu',kernel_initializer='uniform'))  
model.add(MaxPooling2D(pool_size=(2,2)))  
model.add(Conv2D(512,(3,3),strides=(1,1),padding='same',activation='relu',kernel_initializer='uniform'))  
model.add(Conv2D(512,(3,3),strides=(1,1),padding='same',activation='relu',kernel_initializer='uniform'))  
model.add(Conv2D(512,(3,3),strides=(1,1),padding='same',activation='relu',kernel_initializer='uniform'))  
model.add(Conv2D(512,(3,3),strides=(1,1),padding='same',activation='relu',kernel_initializer='uniform'))  
model.add(MaxPooling2D(pool_size=(2,2)))  
model.add(Flatten())  
model.add(Dense(4096,activation='relu'))  
model.add(Dropout(0.5))  
model.add(Dense(4096,activation='relu'))  
model.add(Dropout(0.5))  
model.add(Dense(20,activation='softmax'))  
model.compile(loss='categorical_crossentropy',optimizer='sgd',metrics=['accuracy'])  
model.summary()  

checkpoint = ModelCheckpoint('VGG19.hdf5', verbose = 1, monitor = 'val_accuracy', save_best_only = True)
# Out:
# Using TensorFlow backend.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 224, 224, 64)      1792
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 224, 224, 64)      36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 112, 112, 128)     73856
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 112, 112, 128)     147584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 56, 56, 128)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 56, 56, 256)       295168
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 56, 56, 256)       590080
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 56, 56, 256)       590080
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 56, 56, 256)       590080
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 28, 28, 256)       0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 28, 28, 512)       1180160
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 28, 28, 512)       2359808
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 28, 28, 512)       2359808
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 28, 28, 512)       2359808
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 14, 14, 512)       0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              102764544
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 20)                81940
# =================================================================
# Total params: 139,652,180
# Trainable params: 139,652,180
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 载入数据
path = './Standard/RGB224'
X,y = load_data(path,128,layers=3)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, stratify = y, shuffle = True, random_state = 666)
# Out:
# [('Pikachu', 454), ('Squirtle', 410), ('Bulbasaur', 387), ('Mewtwo', 355), ('Charmander', 354), ('Psyduck', 264), ('Raichu', 174), ('Spearow', 168), ('Muk', 161), ('Aerodactyl', 152), ('Dratini', 151), ('Fearow', 143), ('Shellder', 126), ('Rapidash', 107), ('Mankey', 103), ('Ninetales', 101), ('Sandslash', 99), ('Lapras', 98), ('Pidgey', 97), ('Machamp', 88)]
# Class1:Pikachu
# Class2:Squirtle
# Class3:Bulbasaur
# Class4:Mewtwo
# Class5:Charmander
# Class6:Psyduck
# Class7:Raichu
# Class8:Spearow
# Class9:Muk
# Class10:Aerodactyl
# Class11:Dratini
# Class12:Fearow
# Class13:Shellder
# Class14:Rapidash
# Class15:Mankey
# Class16:Ninetales
# Class17:Sandslash
# Class18:Lapras
# Class19:Pidgey
# Class20:Machamp
# (3992, 224, 224, 3)

# %%
from keras.preprocessing.image import ImageDataGenerator
datagen = ImageDataGenerator(rotation_range = 45, # Degree range for random rotations
    zoom_range = 0.2, # Range for random zoom 
    horizontal_flip = True, # Randomly flip inputs horizontally
    width_shift_range = 0.15, # Range for horizontal shift 
    height_shift_range = 0.15, # Range for vertical shift 
    shear_range = 0.2) # Shear Intensity
datagen.fit(X_train)


#history = model.fit(X_train, y_train, batch_size=16, epochs=100,validation_data = [X_test, y_test],callbacks = [checkpoint])


history = model.fit_generator(datagen.flow(X_train, y_train, batch_size = 16), epochs = 100, validation_data = [X_test, y_test],callbacks = [checkpoint])
# Out:
# Epoch 1/100
# 200/200 [==============================] - 41s 204ms/step - loss: 2.8825 - accuracy: 0.1162 - val_loss: 2.8584 - val_accuracy: 0.1139
#
# Epoch 00001: val_accuracy improved from -inf to 0.11389, saving model to VGG19.hdf5
# Epoch 2/100
# 200/200 [==============================] - 35s 176ms/step - loss: 2.8546 - accuracy: 0.1021 - val_loss: 2.9094 - val_accuracy: 0.0964
#
# Epoch 00002: val_accuracy did not improve from 0.11389
# Epoch 3/100
# 200/200 [==============================] - 34s 169ms/step - loss: 2.8579 - accuracy: 0.1024 - val_loss: 2.8392 - val_accuracy: 0.1126
#
# Epoch 00003: val_accuracy did not improve from 0.11389
# Epoch 4/100
# 200/200 [==============================] - 34s 171ms/step - loss: 2.8483 - accuracy: 0.1037 - val_loss: 2.8333 - val_accuracy: 0.1139
#
# Epoch 00004: val_accuracy did not improve from 0.11389
# Epoch 5/100
# 200/200 [==============================] - 34s 169ms/step - loss: 2.8387 - accuracy: 0.1112 - val_loss: 2.8087 - val_accuracy: 0.1139
#
# Epoch 00005: val_accuracy did not improve from 0.11389
# Epoch 6/100
# 200/200 [==============================] - 35s 175ms/step - loss: 2.8152 - accuracy: 0.1434 - val_loss: 2.7548 - val_accuracy: 0.1715
#
# Epoch 00006: val_accuracy improved from 0.11389 to 0.17146, saving model to VGG19.hdf5
# Epoch 7/100
# 200/200 [==============================] - 34s 171ms/step - loss: 2.7051 - accuracy: 0.1632 - val_loss: 2.5404 - val_accuracy: 0.2228
#
# Epoch 00007: val_accuracy improved from 0.17146 to 0.22278, saving model to VGG19.hdf5
# Epoch 8/100
# 200/200 [==============================] - 34s 172ms/step - loss: 2.5341 - accuracy: 0.2145 - val_loss: 2.4395 - val_accuracy: 0.2228
#
# Epoch 00008: val_accuracy did not improve from 0.22278
# Epoch 9/100
# 200/200 [==============================] - 35s 175ms/step - loss: 2.4674 - accuracy: 0.2324 - val_loss: 2.3796 - val_accuracy: 0.2603
#
# Epoch 00009: val_accuracy improved from 0.22278 to 0.26033, saving model to VGG19.hdf5
# Epoch 10/100
# 200/200 [==============================] - 34s 171ms/step - loss: 2.4785 - accuracy: 0.2333 - val_loss: 2.3397 - val_accuracy: 0.2591
#
# Epoch 00010: val_accuracy did not improve from 0.26033
# Epoch 11/100
# 200/200 [==============================] - 34s 172ms/step - loss: 2.4184 - accuracy: 0.2412 - val_loss: 2.2883 - val_accuracy: 0.2728
#
# Epoch 00011: val_accuracy improved from 0.26033 to 0.27284, saving model to VGG19.hdf5
# Epoch 12/100
# 200/200 [==============================] - 34s 171ms/step - loss: 2.3683 - accuracy: 0.2565 - val_loss: 2.2268 - val_accuracy: 0.2929
#
# Epoch 00012: val_accuracy improved from 0.27284 to 0.29287, saving model to VGG19.hdf5
# Epoch 13/100
# 200/200 [==============================] - 35s 174ms/step - loss: 2.3689 - accuracy: 0.2718 - val_loss: 2.2169 - val_accuracy: 0.3229
#
# Epoch 00013: val_accuracy improved from 0.29287 to 0.32290, saving model to VGG19.hdf5
# Epoch 14/100
# 200/200 [==============================] - 35s 173ms/step - loss: 2.2975 - accuracy: 0.3041 - val_loss: 2.1862 - val_accuracy: 0.3129
#
# Epoch 00014: val_accuracy did not improve from 0.32290
# Epoch 15/100
# 200/200 [==============================] - 35s 175ms/step - loss: 2.2629 - accuracy: 0.3007 - val_loss: 2.0683 - val_accuracy: 0.3642
#
# Epoch 00015: val_accuracy improved from 0.32290 to 0.36421, saving model to VGG19.hdf5
# Epoch 16/100
# 200/200 [==============================] - 35s 173ms/step - loss: 2.2064 - accuracy: 0.3191 - val_loss: 1.9577 - val_accuracy: 0.3980
#
# Epoch 00016: val_accuracy improved from 0.36421 to 0.39800, saving model to VGG19.hdf5
# Epoch 17/100
# 200/200 [==============================] - 34s 168ms/step - loss: 2.1233 - accuracy: 0.3433 - val_loss: 2.0113 - val_accuracy: 0.3630
#
# Epoch 00017: val_accuracy did not improve from 0.39800
# Epoch 18/100
# 200/200 [==============================] - 34s 168ms/step - loss: 2.0856 - accuracy: 0.3439 - val_loss: 1.9691 - val_accuracy: 0.3755
#
# Epoch 00018: val_accuracy did not improve from 0.39800
# Epoch 19/100
# 200/200 [==============================] - 33s 166ms/step - loss: 2.0747 - accuracy: 0.3564 - val_loss: 1.9166 - val_accuracy: 0.3930
#
# Epoch 00019: val_accuracy did not improve from 0.39800
# Epoch 20/100
# 200/200 [==============================] - 33s 164ms/step - loss: 2.0622 - accuracy: 0.3505 - val_loss: 2.1883 - val_accuracy: 0.3054
#
# Epoch 00020: val_accuracy did not improve from 0.39800
# Epoch 21/100
# 200/200 [==============================] - 33s 166ms/step - loss: 2.0031 - accuracy: 0.3692 - val_loss: 1.7961 - val_accuracy: 0.4255
#
# Epoch 00021: val_accuracy improved from 0.39800 to 0.42553, saving model to VGG19.hdf5
# Epoch 22/100
# 200/200 [==============================] - 33s 165ms/step - loss: 1.9389 - accuracy: 0.3959 - val_loss: 1.8078 - val_accuracy: 0.4255
#
# Epoch 00022: val_accuracy did not improve from 0.42553
# Epoch 23/100
# 200/200 [==============================] - 33s 167ms/step - loss: 1.9522 - accuracy: 0.3943 - val_loss: 1.8322 - val_accuracy: 0.4330
#
# Epoch 00023: val_accuracy improved from 0.42553 to 0.43304, saving model to VGG19.hdf5
# Epoch 24/100
# 200/200 [==============================] - 33s 166ms/step - loss: 1.9540 - accuracy: 0.3874 - val_loss: 1.7114 - val_accuracy: 0.4543
#
# Epoch 00024: val_accuracy improved from 0.43304 to 0.45432, saving model to VGG19.hdf5
# Epoch 25/100
# 200/200 [==============================] - 34s 172ms/step - loss: 1.8958 - accuracy: 0.4046 - val_loss: 1.6838 - val_accuracy: 0.4443
#
# Epoch 00025: val_accuracy did not improve from 0.45432
# Epoch 26/100
# 200/200 [==============================] - 34s 168ms/step - loss: 1.8225 - accuracy: 0.4122 - val_loss: 1.8512 - val_accuracy: 0.4230
#
# Epoch 00026: val_accuracy did not improve from 0.45432
# Epoch 27/100
# 200/200 [==============================] - 33s 167ms/step - loss: 1.8174 - accuracy: 0.4347 - val_loss: 1.6093 - val_accuracy: 0.4931
#
# Epoch 00027: val_accuracy improved from 0.45432 to 0.49312, saving model to VGG19.hdf5
# Epoch 28/100
# 200/200 [==============================] - 33s 166ms/step - loss: 1.7670 - accuracy: 0.4482 - val_loss: 1.5961 - val_accuracy: 0.4806
#
# Epoch 00028: val_accuracy did not improve from 0.49312
# Epoch 29/100
# 200/200 [==============================] - 35s 173ms/step - loss: 1.7888 - accuracy: 0.4394 - val_loss: 1.6015 - val_accuracy: 0.4881
#
# Epoch 00029: val_accuracy did not improve from 0.49312
# Epoch 30/100
# 200/200 [==============================] - 34s 169ms/step - loss: 1.7066 - accuracy: 0.4557 - val_loss: 1.7786 - val_accuracy: 0.4706
#
# Epoch 00030: val_accuracy did not improve from 0.49312
# Epoch 31/100
# 200/200 [==============================] - 34s 168ms/step - loss: 1.6884 - accuracy: 0.4764 - val_loss: 2.3583 - val_accuracy: 0.3429
#
# Epoch 00031: val_accuracy did not improve from 0.49312
# Epoch 32/100
# 200/200 [==============================] - 33s 167ms/step - loss: 1.6251 - accuracy: 0.4920 - val_loss: 1.4914 - val_accuracy: 0.5419
#
# Epoch 00032: val_accuracy improved from 0.49312 to 0.54193, saving model to VGG19.hdf5
# Epoch 33/100
# 200/200 [==============================] - 33s 165ms/step - loss: 1.6001 - accuracy: 0.5008 - val_loss: 1.5015 - val_accuracy: 0.5369
#
# Epoch 00033: val_accuracy did not improve from 0.54193
# Epoch 34/100
# 200/200 [==============================] - 34s 172ms/step - loss: 1.5527 - accuracy: 0.5152 - val_loss: 1.5462 - val_accuracy: 0.5081
#
# Epoch 00034: val_accuracy did not improve from 0.54193
# Epoch 35/100
# 200/200 [==============================] - 33s 167ms/step - loss: 1.5477 - accuracy: 0.5218 - val_loss: 1.5063 - val_accuracy: 0.5244
#
# Epoch 00035: val_accuracy did not improve from 0.54193
# Epoch 36/100
# 200/200 [==============================] - 34s 168ms/step - loss: 1.5002 - accuracy: 0.5359 - val_loss: 1.4177 - val_accuracy: 0.5569
#
# Epoch 00036: val_accuracy improved from 0.54193 to 0.55695, saving model to VGG19.hdf5
# Epoch 37/100
# 200/200 [==============================] - 33s 167ms/step - loss: 1.4532 - accuracy: 0.5471 - val_loss: 1.3645 - val_accuracy: 0.5870
#
# Epoch 00037: val_accuracy improved from 0.55695 to 0.58698, saving model to VGG19.hdf5
# Epoch 38/100
# 200/200 [==============================] - 34s 172ms/step - loss: 1.4234 - accuracy: 0.5496 - val_loss: 1.3763 - val_accuracy: 0.5845
#
# Epoch 00038: val_accuracy did not improve from 0.58698
# Epoch 39/100
# 200/200 [==============================] - 33s 166ms/step - loss: 1.4135 - accuracy: 0.5525 - val_loss: 1.4649 - val_accuracy: 0.5394
#
# Epoch 00039: val_accuracy did not improve from 0.58698
# Epoch 40/100
# 200/200 [==============================] - 33s 166ms/step - loss: 1.3794 - accuracy: 0.5694 - val_loss: 1.5566 - val_accuracy: 0.5382
#
# Epoch 00040: val_accuracy did not improve from 0.58698
# Epoch 41/100
# 200/200 [==============================] - 34s 172ms/step - loss: 1.4014 - accuracy: 0.5697 - val_loss: 1.3390 - val_accuracy: 0.5845
#
# Epoch 00041: val_accuracy did not improve from 0.58698
# Epoch 42/100
# 200/200 [==============================] - 34s 169ms/step - loss: 1.3626 - accuracy: 0.5781 - val_loss: 1.3284 - val_accuracy: 0.5970
#
# Epoch 00042: val_accuracy improved from 0.58698 to 0.59700, saving model to VGG19.hdf5
# Epoch 43/100
# 200/200 [==============================] - 34s 170ms/step - loss: 1.3067 - accuracy: 0.6054 - val_loss: 1.3266 - val_accuracy: 0.5870
#
# Epoch 00043: val_accuracy did not improve from 0.59700
# Epoch 44/100
# 200/200 [==============================] - 34s 170ms/step - loss: 1.3310 - accuracy: 0.5822 - val_loss: 1.2065 - val_accuracy: 0.6345
#
# Epoch 00044: val_accuracy improved from 0.59700 to 0.63454, saving model to VGG19.hdf5
# Epoch 45/100
# 200/200 [==============================] - 34s 168ms/step - loss: 1.2773 - accuracy: 0.5929 - val_loss: 1.2582 - val_accuracy: 0.6133
#
# Epoch 00045: val_accuracy did not improve from 0.63454
# Epoch 46/100
# 200/200 [==============================] - 33s 164ms/step - loss: 1.2608 - accuracy: 0.6019 - val_loss: 1.2627 - val_accuracy: 0.6370
#
# Epoch 00046: val_accuracy improved from 0.63454 to 0.63705, saving model to VGG19.hdf5
# Epoch 47/100
# 200/200 [==============================] - 34s 168ms/step - loss: 1.2489 - accuracy: 0.6160 - val_loss: 1.2550 - val_accuracy: 0.6170
#
# Epoch 00047: val_accuracy did not improve from 0.63705
# Epoch 48/100
# 200/200 [==============================] - 34s 171ms/step - loss: 1.3084 - accuracy: 0.6035 - val_loss: 1.1700 - val_accuracy: 0.6471
#
# Epoch 00048: val_accuracy improved from 0.63705 to 0.64706, saving model to VGG19.hdf5
# Epoch 49/100
# 200/200 [==============================] - 34s 170ms/step - loss: 1.2084 - accuracy: 0.6229 - val_loss: 1.2885 - val_accuracy: 0.5957
#
# Epoch 00049: val_accuracy did not improve from 0.64706
# Epoch 50/100
# 200/200 [==============================] - 34s 171ms/step - loss: 1.1778 - accuracy: 0.6273 - val_loss: 1.1282 - val_accuracy: 0.6708
#
# Epoch 00050: val_accuracy improved from 0.64706 to 0.67084, saving model to VGG19.hdf5
# Epoch 51/100
# 200/200 [==============================] - 34s 172ms/step - loss: 1.1752 - accuracy: 0.6276 - val_loss: 1.1672 - val_accuracy: 0.6508
#
# Epoch 00051: val_accuracy did not improve from 0.67084
# Epoch 52/100
# 200/200 [==============================] - 35s 174ms/step - loss: 1.1218 - accuracy: 0.6611 - val_loss: 1.2222 - val_accuracy: 0.6183
#
# Epoch 00052: val_accuracy did not improve from 0.67084
# Epoch 53/100
# 200/200 [==============================] - 33s 166ms/step - loss: 1.1071 - accuracy: 0.6458 - val_loss: 1.1511 - val_accuracy: 0.6558
#
# Epoch 00053: val_accuracy did not improve from 0.67084
# Epoch 54/100
# 200/200 [==============================] - 34s 169ms/step - loss: 1.1019 - accuracy: 0.6558 - val_loss: 1.1787 - val_accuracy: 0.6496
#
# Epoch 00054: val_accuracy did not improve from 0.67084
# Epoch 55/100
# 200/200 [==============================] - 33s 167ms/step - loss: 1.0725 - accuracy: 0.6699 - val_loss: 1.1254 - val_accuracy: 0.6746
#
# Epoch 00055: val_accuracy improved from 0.67084 to 0.67459, saving model to VGG19.hdf5
# Epoch 56/100
# 200/200 [==============================] - 34s 168ms/step - loss: 1.0638 - accuracy: 0.6740 - val_loss: 1.0353 - val_accuracy: 0.6896
#
# Epoch 00056: val_accuracy improved from 0.67459 to 0.68961, saving model to VGG19.hdf5
# Epoch 57/100
# 200/200 [==============================] - 34s 171ms/step - loss: 1.0292 - accuracy: 0.6849 - val_loss: 1.0969 - val_accuracy: 0.6746
#
# Epoch 00057: val_accuracy did not improve from 0.68961
# Epoch 58/100
# 200/200 [==============================] - 33s 165ms/step - loss: 1.0068 - accuracy: 0.6859 - val_loss: 1.0858 - val_accuracy: 0.6846
#
# Epoch 00058: val_accuracy did not improve from 0.68961
# Epoch 59/100
# 200/200 [==============================] - 33s 164ms/step - loss: 0.9789 - accuracy: 0.6921 - val_loss: 1.1905 - val_accuracy: 0.6708
#
# Epoch 00059: val_accuracy did not improve from 0.68961
# Epoch 60/100
# 200/200 [==============================] - 33s 167ms/step - loss: 1.0172 - accuracy: 0.6787 - val_loss: 1.1543 - val_accuracy: 0.6671
#
# Epoch 00060: val_accuracy did not improve from 0.68961
# Epoch 61/100
# 200/200 [==============================] - 33s 166ms/step - loss: 1.0032 - accuracy: 0.6928 - val_loss: 1.1078 - val_accuracy: 0.6796
#
# Epoch 00061: val_accuracy did not improve from 0.68961
# Epoch 62/100
# 200/200 [==============================] - 34s 171ms/step - loss: 0.9921 - accuracy: 0.6950 - val_loss: 1.1038 - val_accuracy: 0.6821
#
# Epoch 00062: val_accuracy did not improve from 0.68961
# Epoch 63/100
# 200/200 [==============================] - 34s 172ms/step - loss: 0.9213 - accuracy: 0.7153 - val_loss: 1.0761 - val_accuracy: 0.6884
#
# Epoch 00063: val_accuracy did not improve from 0.68961
# Epoch 64/100
# 200/200 [==============================] - 34s 171ms/step - loss: 0.9262 - accuracy: 0.7150 - val_loss: 1.0529 - val_accuracy: 0.6859
#
# Epoch 00064: val_accuracy did not improve from 0.68961
# Epoch 65/100
# 200/200 [==============================] - 33s 167ms/step - loss: 0.9155 - accuracy: 0.7181 - val_loss: 1.0136 - val_accuracy: 0.6959
#
# Epoch 00065: val_accuracy improved from 0.68961 to 0.69587, saving model to VGG19.hdf5
# Epoch 66/100
# 200/200 [==============================] - 34s 170ms/step - loss: 0.9063 - accuracy: 0.7178 - val_loss: 1.0655 - val_accuracy: 0.7021
#
# Epoch 00066: val_accuracy improved from 0.69587 to 0.70213, saving model to VGG19.hdf5
# Epoch 67/100
# 200/200 [==============================] - 34s 171ms/step - loss: 0.8667 - accuracy: 0.7294 - val_loss: 1.0087 - val_accuracy: 0.7071
#
# Epoch 00067: val_accuracy improved from 0.70213 to 0.70713, saving model to VGG19.hdf5
# Epoch 68/100
# 200/200 [==============================] - 34s 169ms/step - loss: 0.8426 - accuracy: 0.7385 - val_loss: 1.0527 - val_accuracy: 0.6821
#
# Epoch 00068: val_accuracy did not improve from 0.70713
# Epoch 69/100
# 200/200 [==============================] - 33s 167ms/step - loss: 0.8531 - accuracy: 0.7335 - val_loss: 1.2096 - val_accuracy: 0.6796
#
# Epoch 00069: val_accuracy did not improve from 0.70713
# Epoch 70/100
# 200/200 [==============================] - 34s 170ms/step - loss: 0.8742 - accuracy: 0.7238 - val_loss: 1.0693 - val_accuracy: 0.6859
#
# Epoch 00070: val_accuracy did not improve from 0.70713
# Epoch 71/100
# 200/200 [==============================] - 34s 168ms/step - loss: 0.8318 - accuracy: 0.7397 - val_loss: 0.9569 - val_accuracy: 0.7209
#
# Epoch 00071: val_accuracy improved from 0.70713 to 0.72090, saving model to VGG19.hdf5
# Epoch 72/100
# 200/200 [==============================] - 34s 168ms/step - loss: 0.8120 - accuracy: 0.7488 - val_loss: 1.0108 - val_accuracy: 0.7034
#
# Epoch 00072: val_accuracy did not improve from 0.72090
# Epoch 73/100
# 200/200 [==============================] - 34s 171ms/step - loss: 0.8179 - accuracy: 0.7422 - val_loss: 0.9627 - val_accuracy: 0.7284
#
# Epoch 00073: val_accuracy improved from 0.72090 to 0.72841, saving model to VGG19.hdf5
# Epoch 74/100
# 200/200 [==============================] - 34s 169ms/step - loss: 0.7817 - accuracy: 0.7551 - val_loss: 0.9960 - val_accuracy: 0.7171
#
# Epoch 00074: val_accuracy did not improve from 0.72841
# Epoch 75/100
# 200/200 [==============================] - 33s 166ms/step - loss: 0.7832 - accuracy: 0.7466 - val_loss: 0.9537 - val_accuracy: 0.7196
#
# Epoch 00075: val_accuracy did not improve from 0.72841
# Epoch 76/100
# 200/200 [==============================] - 33s 167ms/step - loss: 0.7782 - accuracy: 0.7573 - val_loss: 0.9990 - val_accuracy: 0.7234
#
# Epoch 00076: val_accuracy did not improve from 0.72841
# Epoch 77/100
# 200/200 [==============================] - 33s 167ms/step - loss: 0.7480 - accuracy: 0.7532 - val_loss: 0.9260 - val_accuracy: 0.7359
#
# Epoch 00077: val_accuracy improved from 0.72841 to 0.73592, saving model to VGG19.hdf5
# Epoch 78/100
# 200/200 [==============================] - 33s 166ms/step - loss: 0.7353 - accuracy: 0.7645 - val_loss: 1.0537 - val_accuracy: 0.6959
#
# Epoch 00078: val_accuracy did not improve from 0.73592
# Epoch 79/100
# 200/200 [==============================] - 34s 169ms/step - loss: 0.7273 - accuracy: 0.7607 - val_loss: 0.8915 - val_accuracy: 0.7547
#
# Epoch 00079: val_accuracy improved from 0.73592 to 0.75469, saving model to VGG19.hdf5
# Epoch 80/100
# 200/200 [==============================] - 35s 175ms/step - loss: 0.7191 - accuracy: 0.7707 - val_loss: 0.9096 - val_accuracy: 0.7635
#
# Epoch 00080: val_accuracy improved from 0.75469 to 0.76345, saving model to VGG19.hdf5
# Epoch 81/100
# 200/200 [==============================] - 34s 170ms/step - loss: 0.7208 - accuracy: 0.7692 - val_loss: 0.9660 - val_accuracy: 0.7359
#
# Epoch 00081: val_accuracy did not improve from 0.76345
# Epoch 82/100
# 200/200 [==============================] - 34s 168ms/step - loss: 0.6901 - accuracy: 0.7767 - val_loss: 0.9823 - val_accuracy: 0.7222
#
# Epoch 00082: val_accuracy did not improve from 0.76345
# Epoch 83/100
# 200/200 [==============================] - 34s 169ms/step - loss: 0.6782 - accuracy: 0.7892 - val_loss: 0.9651 - val_accuracy: 0.7372
#
# Epoch 00083: val_accuracy did not improve from 0.76345
# Epoch 84/100
# 200/200 [==============================] - 33s 166ms/step - loss: 0.7045 - accuracy: 0.7758 - val_loss: 0.9293 - val_accuracy: 0.7422
#
# Epoch 00084: val_accuracy did not improve from 0.76345
# Epoch 85/100
# 200/200 [==============================] - 33s 167ms/step - loss: 0.6542 - accuracy: 0.7905 - val_loss: 0.9872 - val_accuracy: 0.7222
#
# Epoch 00085: val_accuracy did not improve from 0.76345
# Epoch 86/100
# 200/200 [==============================] - 33s 165ms/step - loss: 0.6318 - accuracy: 0.8033 - val_loss: 0.9362 - val_accuracy: 0.7497
#
# Epoch 00086: val_accuracy did not improve from 0.76345
# Epoch 87/100
# 200/200 [==============================] - 33s 167ms/step - loss: 0.6304 - accuracy: 0.7992 - val_loss: 0.9223 - val_accuracy: 0.7397
#
# Epoch 00087: val_accuracy did not improve from 0.76345
# Epoch 88/100
# 200/200 [==============================] - 34s 170ms/step - loss: 0.6666 - accuracy: 0.7880 - val_loss: 1.0578 - val_accuracy: 0.7096
#
# Epoch 00088: val_accuracy did not improve from 0.76345
# Epoch 89/100
# 200/200 [==============================] - 33s 167ms/step - loss: 0.6311 - accuracy: 0.7961 - val_loss: 0.9808 - val_accuracy: 0.7584
#
# Epoch 00089: val_accuracy did not improve from 0.76345
# Epoch 90/100
# 200/200 [==============================] - 34s 168ms/step - loss: 0.6315 - accuracy: 0.7967 - val_loss: 0.9907 - val_accuracy: 0.7297
#
# Epoch 00090: val_accuracy did not improve from 0.76345
# Epoch 91/100
# 200/200 [==============================] - 34s 170ms/step - loss: 0.6110 - accuracy: 0.7999 - val_loss: 0.8133 - val_accuracy: 0.7484
#
# Epoch 00091: val_accuracy did not improve from 0.76345
# Epoch 92/100
# 200/200 [==============================] - 33s 167ms/step - loss: 0.5970 - accuracy: 0.8074 - val_loss: 0.9259 - val_accuracy: 0.7509
#
# Epoch 00092: val_accuracy did not improve from 0.76345
# Epoch 93/100
# 200/200 [==============================] - 33s 165ms/step - loss: 0.5827 - accuracy: 0.8115 - val_loss: 0.8352 - val_accuracy: 0.7685
#
# Epoch 00093: val_accuracy improved from 0.76345 to 0.76846, saving model to VGG19.hdf5
# Epoch 94/100
# 200/200 [==============================] - 35s 173ms/step - loss: 0.5677 - accuracy: 0.8168 - val_loss: 0.9728 - val_accuracy: 0.7234
#
# Epoch 00094: val_accuracy did not improve from 0.76846
# Epoch 95/100
# 200/200 [==============================] - 33s 167ms/step - loss: 0.5597 - accuracy: 0.8243 - val_loss: 1.0847 - val_accuracy: 0.7159
#
# Epoch 00095: val_accuracy did not improve from 0.76846
# Epoch 96/100
# 200/200 [==============================] - 33s 164ms/step - loss: 0.5371 - accuracy: 0.8246 - val_loss: 0.9469 - val_accuracy: 0.7660
#
# Epoch 00096: val_accuracy did not improve from 0.76846
# Epoch 97/100
# 200/200 [==============================] - 34s 169ms/step - loss: 0.5814 - accuracy: 0.8171 - val_loss: 1.0112 - val_accuracy: 0.7171
#
# Epoch 00097: val_accuracy did not improve from 0.76846
# Epoch 98/100
# 200/200 [==============================] - 34s 170ms/step - loss: 0.5353 - accuracy: 0.8312 - val_loss: 0.9314 - val_accuracy: 0.7635
#
# Epoch 00098: val_accuracy did not improve from 0.76846
# Epoch 99/100
# 200/200 [==============================] - 34s 171ms/step - loss: 0.5205 - accuracy: 0.8356 - val_loss: 0.8892 - val_accuracy: 0.7610
#
# Epoch 00099: val_accuracy did not improve from 0.76846
# Epoch 100/100
# 200/200 [==============================] - 34s 171ms/step - loss: 0.5084 - accuracy: 0.8331 - val_loss: 0.8428 - val_accuracy: 0.7697
#
# Epoch 00100: val_accuracy improved from 0.76846 to 0.76971, saving model to VGG19.hdf5

# %%
import matplotlib.pyplot as plt
# Plot learning curves
fig = plt.figure(figsize = (17, 4))
    
plt.subplot(121)
plt.plot(history.history['accuracy'], label = 'acc')
plt.plot(history.history['val_accuracy'], label = 'val_acc')
plt.legend()
plt.grid()
plt.title(f'accuracy')

plt.subplot(122)
plt.plot(history.history['loss'], label = 'loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.legend()
plt.grid()
plt.title(f'loss')
plt.savefig("./Image/VGG19_sgd_epoch100_beach_size16_gendata.png")

# %%
# 保存模型
model.save("./Model/VGG19_sgd_epoch100_beach_size16_gendata")
